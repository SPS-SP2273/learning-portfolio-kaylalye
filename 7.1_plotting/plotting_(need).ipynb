# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %% [markdown]
# ### Things to note

# %%
#data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10 ,12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

plt.plot(x, y_1, label = 'Y values',
         color = 'red', linestyle = 'dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=0.25) #changes the opacity of grid lines)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.2 Adding another plot

# %%
#data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10 ,12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

plt.plot(x, y_1, label = 'Y1 values',
         color = 'red', linestyle = 'dashed')
plt.plot(x, y_2,
         label = 'Y2 values', c = 'blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=0.25) #changes the opacity of grid lines)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
#data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10 ,12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

plt.plot(x, y_1, label = 'Y1 values',
         color = 'red', linestyle = 'dashed')
plt.plot(x, y_2,
         label = 'Y2 values', c = 'blue')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
         label = 'Y3 with errors', color = 'green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=0.25) #changes the opacity of grid lines)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np

x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10 ,12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, c='red', ls='dashed', label = 'Y1 Values')
plt.plot(np_x, np_y_2, c='blue', label='Y2 Values')
plt.xlabel('X-values')
plt.ylabel('Y-values')
plt.title('X vs Y')
plt.grid(alpha=0.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', c='red', ls='dashed')
plt.plot(x, sin_x, label='sin(x)', c='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', c='red', ls='dashed')
plt.legend(loc='lower left')

plt.twinx()
#creates a new y-axis for the next plot

plt.plot(x, sin_x, label='sin(x)', c='blue')
plt.legend(loc='lower right')

# %% [markdown]
# ### Things to note

# %%
x = np.linspace(0, 6, 100)
#creates evenly spaced values over the range given
#np.linspace(start, stop, number of points)

x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', c='red', ls='dashed')
plt.legend(loc='lower left')

plt.twinx()
#creates a new y-axis for the next plot

plt.plot(x, sin_x, label='sin(x)', c='blue')
plt.legend(loc='lower right')

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', c='red', ls='dashed')
plt.legend(loc='lower left')

plt.twinx()

plt.plot(x, sin_x, label='sin(x)', c='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24) #skips the rows in the beginning eg for headers
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
#alpha softens the colour of the plot
plt.ylim([-8, 8])

# %%
plt.hlines(0, date[0], date[-1], ls='--', c='grey')
#needs a y-values and starting and ending x-values

# %% [markdown]
# ## 4.2 Styles

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### xkcd!

# %%
plt.xkcd()
#instead of style

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')
